# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)),
                      columns=['mat'], index = range(1, 101))
df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)),
                      columns=['por'], index = range(1, 101))
df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)),
                      columns=['geo'], index = range(1, 101))
df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)),
                      columns=['ing'], index = range(1, 101))
df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)),
                      columns=['his'], index = range(1, 101))
df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)),
                      columns=['fis'], index = range(1, 101))
df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)),
                      columns=['qui'], index = range(1, 101))

# %%
#i:
Pc_acertos= pd.DataFrame(df_mat/24)
Pc_acertos= Pc_acertos.rename(columns = {"mat": "Pc acertos mat"})
Pc_acertos["Pc acertos por"] = df_por/18
Pc_acertos["Pc acertos geo"] = df_geo/8
Pc_acertos["Pc acertos ing"] = df_ing/8
Pc_acertos["Pc acertos his"] = df_his /  8
Pc_acertos["Pc acertos fis"] = df_fis /  8
Pc_acertos["Pc acertos qui"] = df_qui /  8
Pc_acertos
# Out:
#      Pc acertos mat  Pc acertos por  Pc acertos geo  Pc acertos ing  \
# 1          0.250000        0.388889           0.875           0.375
# 2          0.791667        0.555556           0.000           0.000
# 3          0.583333        0.888889           0.000           0.625
# 4          0.416667        0.388889           0.375           0.500
# 5          0.291667        0.111111           0.250           0.875
# ..              ...             ...             ...             ...
# 96         0.250000        0.222222           0.875           0.125
# 97         0.333333        0.055556           0.500           0.750
# 98         0.958333        0.277778           0.000           0.250
# 99         0.000000        0.555556           0.375           0.125
# 100        0.458333        0.833333           0.000           0.125
#
#      Pc acertos his  Pc acertos fis  Pc acertos qui
# 1             0.125           1.000           0.375
# ...

# %%
#ii:
Qt_acertos= (df_mat)
Qt_acertos= Qt_acertos.rename(columns = {"mat": "Qt acertos mat"})
Qt_acertos["Qt acertos por"] = df_por
Qt_acertos["Qt acertos geo"] = df_geo
Qt_acertos["Qt acertos ing"] = df_ing
Qt_acertos["Qt acertos his"] = df_his
Qt_acertos["Qt acertos fis"] = df_fis
Qt_acertos["Qt acertos qui"] = df_qui
Qt_acertos["Total"] = Qt_acertos.sum(axis = 1)
Qt_acertos
# Out:
#      Qt acertos mat  Qt acertos por  Qt acertos geo  Qt acertos ing  \
# 1                 6               7               7               3
# 2                19              10               0               0
# 3                14              16               0               5
# 4                10               7               3               4
# 5                 7               2               2               7
# ..              ...             ...             ...             ...
# 96                6               4               7               1
# 97                8               1               4               6
# 98               23               5               0               2
# 99                0              10               3               1
# 100              11              15               0               1
#
#      Qt acertos his  Qt acertos fis  Qt acertos qui  Total
# 1                 1               8               3     35
# ...

# %%
#iii:
Pc_cada_aluno = Soma_cada_aluno/90
Qt_acertos["Pc_cada_aluno"] = Pc_cada_aluno
Qt_acertos
# Out:
#      Qt acertos mat  Qt acertos por  Qt acertos geo  Qt acertos ing  \
# 1                 6               7               7               3
# 2                19              10               0               0
# 3                14              16               0               5
# 4                10               7               3               4
# 5                 7               2               2               7
# ..              ...             ...             ...             ...
# 96                6               4               7               1
# 97                8               1               4               6
# 98               23               5               0               2
# 99                0              10               3               1
# 100              11              15               0               1
#
#      Qt acertos his  Qt acertos fis  Qt acertos qui  Total  Pc_cada_aluno
# 1                 1               8               3     35       0.388889
# ...

# %%
#iv:
len(Qt_acertos[Qt_acertos['Total'] > 45])
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
#i:
Zero_mat=pd.DataFrame(Qt_acertos["Qt acertos mat"].loc
                      [Qt_acertos["Qt acertos mat"] == 0]) 
Zero_fis=pd.DataFrame(Qt_acertos['Qt acertos fis'].loc
                      [Qt_acertos['Qt acertos fis'] == 0]) 
Zero_qui=pd.DataFrame(Qt_acertos['Qt acertos qui'].loc
                      [Qt_acertos['Qt acertos qui'] == 0]) 
Desqualificados=pd.concat([Zero_qui, Zero_fis,Zero_mat], axis = 1)
Desqualificados
# Out:
#     Qt acertos qui  Qt acertos fis  Qt acertos mat
# 4              NaN             0.0             NaN
# 7              NaN             0.0             NaN
# 11             0.0             NaN             NaN
# 13             NaN             0.0             NaN
# 15             0.0             NaN             NaN
# 21             0.0             NaN             NaN
# 26             NaN             NaN             0.0
# 27             0.0             0.0             NaN
# 28             0.0             NaN             NaN
# 34             0.0             NaN             NaN
# 36             NaN             0.0             NaN
# 50             NaN             0.0             NaN
# 57             NaN             0.0             NaN
# 66             NaN             0.0             NaN
# 67             NaN             0.0             NaN
# 73             NaN             0.0             NaN
# 74             NaN             0.0             NaN
# ...

# %%
#ii
print("Total de desqualificados:",len(Desqualificados))
# Out:
# Total de desqualificados: 23

# %%
#iii
notas_his_mat = np.array(pd.DataFrame(Qt_acertos["Qt acertos his"].loc
                      [Qt_acertos['Qt acertos mat'] == 0])) 
notas_his_fis = np.array(pd.DataFrame(Qt_acertos["Qt acertos his"].loc
                      [Qt_acertos['Qt acertos fis'] == 0]))
notas_his_qui = np.array(pd.DataFrame(Qt_acertos["Qt acertos his"].loc
                      [Qt_acertos['Qt acertos qui'] == 0]))
media_his =  (notas_his_mat.mean()+notas_his_fis.mean()+notas_his_qui.mean())/3
notas_geo_mat = np.array(pd.DataFrame(Qt_acertos["Qt acertos geo"].loc
                      [Qt_acertos['Qt acertos mat'] == 0])) 
notas_geo_fis = np.array(pd.DataFrame(Qt_acertos["Qt acertos geo"].loc
                      [Qt_acertos['Qt acertos fis'] == 0]))
notas_geo_qui = np.array(pd.DataFrame(Qt_acertos["Qt acertos geo"].loc
                      [Qt_acertos['Qt acertos qui'] == 0]))
media_geo = (notas_geo_mat.mean()+notas_geo_fis.mean()+notas_geo_qui.mean())/3
media_his, media_geo
# Out:
# (3.2592592592592595, 3.4537037037037037)

# %%
#iv
y = pd.concat([Qt_acertos,Qt_acertos[Qt_acertos['Total'] > 45] ]).drop_duplicates(keep=False)
w=pd.concat([Qt_acertos,Qt_acertos[Qt_acertos['Qt acertos qui'] ==0] ]).drop_duplicates(keep=False)
h= pd.concat([Qt_acertos,Qt_acertos[Qt_acertos['Qt acertos fis'] == 0] ]).drop_duplicates(keep=False)
z=pd.concat([Qt_acertos,Qt_acertos[Qt_acertos['Qt acertos mat'] == 0] ]).drop_duplicates(keep=False)
Aprovados = pd.merge(y, w,  how = 'inner')
Aprovados = pd.merge(Aprovados, z, how = 'inner')
Aprovados =pd.merge(Aprovados, h, how = 'inner')
Aprovados
# Out:
#     Qt acertos mat  Qt acertos por  Qt acertos geo  Qt acertos ing  \
# 0                6               7               7               3
# 1                7               2               2               7
# 2               10               6               3               6
# 3               23               6               2               0
# 4                3               7               2               0
# 5               23               1               2               3
# 6                2               0               6               2
# 7                1               2               7               6
# 8               11               7               3               5
# 9                5               2               0               5
# 10               1               0               0               5
# 11              11               2               7               7
# 12              16               0               0               2
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'
df = pd.read_csv(arquivo, sep=';')

# %%
#i
df.shape[0]
# Out:
# 174191

# %%
#ii
df['paciente_id'].nunique()
# Out:
# 125009

# %%
#iii
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 124185

# %%
#iv
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 49

# %%
#v
df['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
#i
menor_vac = df[df["paciente_idade"]<18].loc[df['vacina_descricao_dose'] == primeira_dose]
pd.DataFrame(menor_vac).copy()
# Out:
#                                       document_id  \
# 1659    acd193a2-9d85-4861-abfc-c155f32bf7e8-i0b0
# 15757   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 28570   449dcd9c-6404-42c2-9629-e6ccc6d1d186-i0b0
# 29435   6b414941-eea7-49b2-a1a5-5c618cd5a77b-i0b0
# 30514   5d97dc04-c9d8-4a83-9c7e-967a660b6c55-i0b0
# 34846   db3fad15-3688-484e-908e-2f0921c38dfc-i0b0
# 38026   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 41025   45899bdb-6e8c-4f90-94c7-773d894f371b-i0b0
# 41169   6e2e5ea1-0aae-4e51-9129-45c78d012a93-i0b0
# 42189   7d9e37d4-27a8-4cba-bca7-0c1b2d0575fa-i0b0
# 46891   f0142540-1a3f-4882-ba3b-467d55f38dc0-i0b0
# 51142   1481a148-e03b-4205-82b5-17125fe42945-i0b0
# 52410   0ffb7fc2-f8cc-41fe-9646-d479628f6323-i0b0
# 59025   17276c54-f153-48a9-a03e-13ddf7d29e2a-i0b0
# 66400   647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 67140   1eb690de-c2aa-4c88-8943-29bd1019d0c4-i0b0
# 68894   88201a10-32b4-4045-a8ae-4df6d3899fb6-i0b0
# 69728   31e0bb5f-4a59-498f-b0f3-b418e653c671-i0b0
# ...

# %%
#ii
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
#iii
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
#iv
Colunas = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
#v
df_menor_lista = df_menor.loc[:,Colunas]
df_menor_lista
# Out:
#         estabelecimento_valor  \
# 1659                  2001748
# 15757                 6159087
# 28570                 6955525
# 29435                 6428940
# 30514                 7625855
# 34846                 6159087
# 38026                 6917291
# 41025                 6992811
# 41169                 6992811
# 42189                 6430201
# 46891                 9648968
# 49016                 6748759
# 51142                 7625855
# 52410                 6430201
# 59025                 6159087
# 61676                 6308740
# 66400                 2000040
# 67140                 7625855
# 68894                 6917682
# 69728                 6955525
# 71721                 7123043
# 77359                 6748759
# 81747                 6748759
# 82096                 5336171
# 83559                 6308740
# 85301                 2001748
# 88494                 7625855
# 89795                 2001314
# 100901                6697151
# 105718                6612385
# ...

# %%
df_menor_lista.drop_duplicates()
# Out:
#         estabelecimento_valor  \
# 1659                  2001748
# 15757                 6159087
# 28570                 6955525
# 29435                 6428940
# 30514                 7625855
# 38026                 6917291
# 41025                 6992811
# 42189                 6430201
# 46891                 9648968
# 49016                 6748759
# 61676                 6308740
# 66400                 2000040
# 68894                 6917682
# 71721                 7123043
# 82096                 5336171
# 89795                 2001314
# 100901                6697151
# 105718                6612385
# 163788                3323307
#
#                               estabelecimento_razaosocial  \
# 1659                 PREFEITURA MUNICIPAL DE PORTO WALTER
# 15757             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 28570   DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 29435                PREFEITURA MUNICIPAL DE ASSIS BRASIL
# ...
